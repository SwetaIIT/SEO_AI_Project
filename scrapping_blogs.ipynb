# %% [markdown]
# <a href="https://colab.research.google.com/github/SwetaIIT/SEO_AI_Project/blob/file/scrapping_blogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article(url):
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print("Error fetching the page:", e)
        return None

    soup = BeautifulSoup(response.text, "html.parser")

    # Extract title
    title = soup.title.text.strip() if soup.title else "No Title Found"

    # Extract paragraphs
    paragraphs = []
    for p in soup.find_all("p"):
        text = p.get_text(strip=True)
        if text:
            paragraphs.append(text)

    return {
        "title": title,
        "content": paragraphs
    }


def save_to_file(data, filename="article.txt"):
    if not data:
        return

    with open(filename, "w", encoding="utf-8") as f:
        f.write(f"Title: {data['title']}\n\n")

        for para in data["content"]:
            f.write(para + "\n\n")


if __name__ == "__main__":
    url = "https://rosssimmonds.com/blog/visibility-llms/"

    article = scrape_article(url)

    if article:
        print("Scraping successful ✅")
        save_to_file(article, "ross_simmonds_article.txt")
# Out:
# Scraping successful ✅

# %%
import requests

img_url = "https://rosssimmonds.com/blog/visibility-llms/"
img_data = requests.get(img_url).content

with open("image.jpg", "wb") as f:
    f.write(img_data)

# %%
from typing import Text
import csv

with open("blog.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Content"])
    writer.writerow([Text])
